# %%
# %load_ext autoreload
# %autoreload 2

# %%
# !pip install -r requirements.txt
# Out:
# ...
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: C:\Users\nikit\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import seaborn as sns
import numpy as np 

from src.pipelines.simple_forecaster import multi_model_forecast

# %%
df = pd.read_excel('example.xlsx')

# %%
df
# Out:
#          Дата         sold       unsold  hidden unsold
# 0  2020-01-01  43874642.76  37239888.21    26348080.89
# 1  2020-02-01  42722019.09  35597505.12    24529580.67
# 2  2020-03-01  43398524.47  34680760.38    22990357.04
# 3  2020-04-01  43614432.76  33980906.36    22653181.62
# 4  2020-05-01  42737331.66  32930309.82    24111721.27
# ..        ...          ...          ...            ...
# 71 2025-12-01  39143026.43  54691253.48    26924849.65
# 72 2026-01-01  36467703.67  52899193.47    26868399.55
# 73 2026-02-01  36854518.63  52562993.46    26562210.80
# 74 2026-03-01  37202886.02  52362424.45    28216914.34
# 75 2026-04-01  36748697.70  53043857.48    29083752.07
#
# [76 rows x 4 columns]

# %%
y
# Out:
#                    ds            y
# ds
# 2020-01-01 2020-01-01  43874642.76
# 2020-02-01 2020-02-01  42722019.09
# 2020-03-01 2020-03-01  43398524.47
# 2020-04-01 2020-04-01  43614432.76
# 2020-05-01 2020-05-01  42737331.66
# ...               ...          ...
# 2025-12-01 2025-12-01  39143026.43
# 2026-01-01 2026-01-01  36467703.67
# 2026-02-01 2026-02-01  36854518.63
# 2026-03-01 2026-03-01  37202886.02
# 2026-04-01 2026-04-01  36748697.70
#
# [76 rows x 2 columns]

# %%
[df['Дата'] >= pd.to_datetime('2021-01-01')]
# Out:
# [0     False
#  1     False
#  2     False
#  3     False
#  4     False
#        ...
#  71     True
#  72     True
#  73     True
#  74     True
#  75     True
#  Name: Дата, Length: 76, dtype: bool]

# %%
df['unsold/sold'] = (df['unsold']+df['hidden unsold'])/df['sold']
df['unsold+hu'] = (df['unsold']+df['hidden unsold'])
y = df[['Дата', 'sold']]
return_data = multi_model_forecast(y, 20, test_size = 6, seasonal_periods = 12, freq = 'MS', model_list = ['stl_arima', 'es', 'ensemble'], graph = True)
# Out:
# D:\University\Диплом\simple_forecaster\src\pipelines\simple_forecaster.py:24: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\nikit\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning:
#
# Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#
# C:\Users\nikit\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning:
#
# Non-invertible starting MA parameters found. Using zeros as starting parameters.
# Applying Ljung-Box penalty: min p-value = 0.0015
# Final penalized WAPE: 19.5955, Params penalty: Yes, Ljung-Box penalty applied: Yes, model params: ar.L1    -1.250756e-01
# ...

# %%
return_data['plots']

# %%
train_data = pd.DataFrame()

# %%
train_data['arima'] = return_data['pred_stat']['arima']['train_pred']
train_data['ES'] = return_data['pred_stat']['es']['train_pred']
train_data['ensemble'] = return_data['pred_stat']['ensemble']['train_pred']
train_data = train_data.reset_index()
train_data['Исходный ряд'] = df['sold'][:-int(len(df['sold'])*0.05)].reset_index(drop = True)

# %%
train_data_melt = train_data.reset_index(drop = True).melt(id_vars = 'ds')

# %%
sns.lineplot(train_data_melt, x = 'ds', y = 'value',  hue = 'variable')
# Out:
# C:\Users\nikit\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_base.py:948: FutureWarning:
#
# When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#
# C:\Users\nikit\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_base.py:948: FutureWarning:
#
# When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#
# C:\Users\nikit\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_base.py:948: FutureWarning:
#
# When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#
# ...

# %%
import plotly.express as px

# %%
return_data['pred_stat']
# Out:
# {'arima': {'model': <statsmodels.tsa.forecasting.stl.STLForecastResults at 0x1533f835cc0>,
#   'train_pred': ds
#   2020-01-01    4.317072e+07
#   2020-02-01    4.305243e+07
#   2020-03-01    4.379465e+07
#   2020-04-01    4.399631e+07
#   2020-05-01    4.342262e+07
#                     ...
#   2025-06-01    3.750328e+07
#   2025-07-01    3.689355e+07
#   2025-08-01    3.789052e+07
#   2025-09-01    3.773622e+07
#   2025-10-01    3.782746e+07
#   Freq: MS, Name: predicted_mean, Length: 70, dtype: float64,
#   'test_pred': ds
#   2025-11-01    3.697753e+07
#   2025-12-01    3.674464e+07
#   2026-01-01    3.250979e+07
#   2026-02-01    3.192405e+07
#   2026-03-01    3.193747e+07
#   2026-04-01    3.190780e+07
#   2026-05-01    3.224992e+07
#   2026-06-01    3.304575e+07
#   2026-07-01    3.291458e+07
#   2026-08-01    3.337611e+07
#   2026-09-01    3.384433e+07
#   2026-10-01    3.364007e+07
#   2026-11-01    3.294558e+07
#   2026-12-01    3.282680e+07
#   2027-01-01    2.888831e+07
# ...

# %%
stl_arima = return_data['pred_stat']['arima']['model']

# Быстрая визуализация всех компонентов
return_data['pred_stat']['arima']['model'].result.plot()

# %%
[method for method in dir(stl_arima) if not method.startswith('__')]
# Out:
# ['_endog',
#  '_get_seasonal_prediction',
#  '_index',
#  '_model',
#  '_model_result',
#  '_nobs',
#  '_result',
#  '_seasonal_forecast',
#  '_stl',
#  'forecast',
#  'get_prediction',
#  'model',
#  'model_result',
#  'period',
#  'result',
#  'stl',
#  'summary']

# %%
print(stl_arima.model_result.params)
# Out:
# const     4.477772e+07
# x1       -1.443155e+05
# ar.L1     1.244886e+00
# ar.L2     3.952052e-01
# ar.L3    -6.706965e-01
# ma.L1    -1.579565e-01
# ma.L2    -8.917147e-01
# ma.L3     1.724060e-01
# sigma2    8.613420e+11
# dtype: float64

# %%
stl_arima.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                     STL Decomposition and SARIMAX Results
# ...
# Dep. Variable:                      y   No. Observations:                   70
# Model:                 ARIMA(3, 0, 3)   Log Likelihood                -994.016
# Date:                Sun, 17 May 2026   AIC                           2006.032
# Time:                        19:58:58   BIC                           2025.739
# Sample:                    01-01-2020   HQIC                          2013.819
#                          - 10-01-2025
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       4.478e+07   1126.020   3.98e+04      0.000    4.48e+07    4.48e+07
# x1         -1.443e+05   3.69e+04     -3.906      0.000   -2.17e+05   -7.19e+04
# ...

# %%
train_data_melt['variable'].unique()
# Out:
# array(['arima', 'ES', 'ensemble', 'Исходный ряд'], dtype=object)

# %%
import plotly.express as px

# %%
px.line(train_data_melt[train_data_melt['variable'].isin(['arima', 'ES', 'Исходный ряд'])], x = 'ds', y = 'value',  color = 'variable', template = 'plotly_white')
# Out:
# C:\Users\nikit\AppData\Local\Programs\Python\Python310\lib\site-packages\plotly\express\_core.py:2065: FutureWarning:
#
# When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.

# %%
sns.lineplot(train_data['Исходный ряд'] - train_data['arima'].values)
# sns.lineplot((train_data['Исходный ряд'] - train_data['ES'])[23:].values)
# Out:
# <Axes: ylabel='Исходный ряд'>

# %%
return_data['pred_stat']['es']['model'].summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                        ExponentialSmoothing Model Results
# ...
# Dep. Variable:                        y   No. Observations:                   70
# Model:             ExponentialSmoothing   SSE                 83262113709072.391
# Optimized:                        False   AIC                           1978.316
# Trend:                   Multiplicative   BIC                           2014.292
# Seasonal:                      Additive   AICC                          1991.728
# Seasonal Periods:                    12   Date:                 Sun, 17 May 2026
# Box-Cox:                          False   Time:                         19:59:01
# Box-Cox Coeff.:                    None
# ...
#                           coeff                 code              optimized
# ---------------------------------------------------------------------------------
# smoothing_level               0.7479433                alpha                False
# ...

# %%
prop_res = train_data['Исходный ряд'] - train_data['arima']
import matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
def acf_chacf(sr):
    fig, axes = plt.subplots(1, 2, figsize=(16, 5))
    
    # ACF
    plot_acf(sr, lags=20, ax=axes[0], zero=False)
    # PACF
    plot_pacf(sr, lags=20, ax=axes[1], method='ols', zero=False)
    
    plt.show()
    
acf_chacf(prop_res[:])

import statsmodels.api as sm
sm.stats.acorr_ljungbox(prop_res[:], lags=[20], return_df=True)
# Out:
#       lb_stat  lb_pvalue
# 20  27.842406   0.113183

# %%
return_data['test_res']
# Out:
#               Test_MAE  Test_MAPE     Test_RMSE  Test_WAPE
# Model
# arima     3.777783e+06  10.169078  4.051910e+06  10.088976
# es        1.746818e+06   4.709753  2.047473e+06   4.665065
# ensemble  2.252085e+06   6.067935  2.529542e+06   6.014437

# %%
y = df[['Дата', 'unsold']]
return_data = multi_model_forecast(y, 12, test_size = 0.05, seasonal_periods = 12, freq = 'MS', model_list = ['stl_arima', 'es', 'ensemble'], graph = True)

# %%
return_data['test_res']
# Out:
#               Test_MAE  Test_MAPE     Test_RMSE  Test_WAPE
# Model
# arima     1.217918e+06   2.258989  1.257141e+06   2.249425
# es        8.327848e+05   1.566764  1.253681e+06   1.538106
# ensemble  8.162255e+05   1.535703  1.225448e+06   1.507522

# %%
fig = return_data['plots']

fig.update_layout(
    margin=dict(t=100),
    height = 600# Увеличьте значение t (top), по умолчанию там обычно 60-80
)

# %%
df['unsold/sold'] = df['unsold']/df['sold']
y = df[['Дата', 'unsold/sold']]
return_data = multi_model_forecast(y, 12, test_size = 0.05, seasonal_periods = 12, freq = 'MS', model_list = ['stl_arima', 'es', 'ensemble'], graph = True)
# Out:
# C:\Users\nikit\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning:
#
# Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#
# C:\Users\nikit\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\tsa\holtwinters\model.py:903: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.

# %%
return_data['plots']

# %%
y = df[['Дата', 'sold']]
pred_stat, stat_df = multi_model_forecast(y, 24, test_size = 0.2, seasonal_preiod = 12, freq = 'MS', value_name = 'sold')
# Out:
#                    ADF      KPSS        PP
# Исходный ряд  0.481076  0.011852  0.563503
# 22:53:25 - cmdstanpy - INFO - Chain [1] start processing
# 22:53:27 - cmdstanpy - INFO - Chain [1] done processing
# [I 2026-04-14 22:53:27,417] A new study created in memory with name: no-name-9b2c0a61-ba4c-4cc3-82e5-b36b1c57d110
# c:\Users\nikit\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# c:\Users\nikit\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# ...

# %%
y = df[['Дата', 'unsold']]
pred_stat, stat_df = multi_model_forecast(y, 24, test_size = 0.2, seasonal_preiod = 12, freq = 'MS', value_name = 'unsold')
# Out:
# D:\University\Диплом\simple_forecaster\forecaster.py:152: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   result.loc['Исходный ряд', 'KPSS'] = kpss(series)[1]
#                   ADF  KPSS        PP
# Исходный ряд  0.97834  0.01  0.989903
# 11:57:30 - cmdstanpy - INFO - Chain [1] start processing
# 11:57:31 - cmdstanpy - INFO - Chain [1] done processing
# C:\Users\nikit\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# D:\University\Диплом\simple_forecaster\forecaster.py:346: FutureWarning: the 'damped' keyword is deprecated, use 'damped_trend' instead.
# ...

# %%
df['sold/unsold'] = df['sold']/df['unsold']
y = df[['Дата', 'sold/unsold']]
pred_stat, stat_df = multi_model_forecast(y, 24, test_size = 0.2, seasonal_preiod = 12, freq = 'MS', value_name = 'sold/unsold')
# Out:
# D:\University\Диплом\simple_forecaster\forecaster.py:152: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   result.loc['Исходный ряд', 'KPSS'] = kpss(series)[1]
#                    ADF  KPSS        PP
# Исходный ряд  0.821263  0.01  0.848129
# 11:58:01 - cmdstanpy - INFO - Chain [1] start processing
# 11:58:02 - cmdstanpy - INFO - Chain [1] done processing
# D:\University\Диплом\simple_forecaster\forecaster.py:346: FutureWarning: the 'damped' keyword is deprecated, use 'damped_trend' instead.
#   exp_model = ExponentialSmoothing(endog = y_train['y'], seasonal_periods = seasonal_preiod, **study.best_params).fit()
#           Test_MAE  Test_MAPE  Test_RMSE  Test_WAPE  Train_MAE  Train_MAPE  \
# Model
# prop      0.181561  26.227871   0.190220  26.238720   0.118259   11.617957
# ar        0.022743   3.273085   0.027277   3.286791   0.037686    3.443830
# ...

# %%
pred_stat['Ensemble']['weights']
# Out:
# {'prop': 0.09477147742380473,
#  'ar': 0.29739601333432736,
#  'exp': 0.6078325092418678}
